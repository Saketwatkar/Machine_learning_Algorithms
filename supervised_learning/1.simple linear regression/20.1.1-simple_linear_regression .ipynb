# %% [markdown]
# ## *Practical execution of simple linear regression

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
## Plot scatter plot
plt.figure(figsize=(5, 3))
plt.scatter(df['Weight'], df['Height'])

# %%
## finding the correlation
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
## Seaborn for visualization
import seaborn as sns
sns.pairplot(df)
plt.gcf().set_size_inches(5, 5)

# %%
## Independent and dependent features
X = df[['Weight']] ## independent feature should be in dataframe or in 2 dimensional array {like-(24,1)}
y = df['Height'] ## dependent feature should be in 1 dimensional array

# %%
x_series=df['Weight'] # when we use single bracket it basically converts the data into a series or 1 dimensional array and we dont need that its gives errors
np.array(x_series).shape
# Out:
# (23,)

# %%
## Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
## Standardization applying z-score (mean=0, std=1) on  independent features X
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train=scaler.fit_transform(X_train)
    ## we only use transform on test data not fit_transform 
                                    ## because we dont want to change the mean and std of test data and the 
                                    # data should be leak for test data

# %%
x_test=scaler.transform(X_test)

# %%
x_test
# Out:
# array([[ 0.33497168],
#        [ 0.33497168],
#        [-1.6641678 ],
#        [ 1.36483141],
#        [-0.45256812],
#        [ 1.97063125]])

# %%
## Apply Linear Regression
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression(n_jobs=-1) ## n_jobs=-1 means use all processors

# %%
regression.fit(x_train, y_train) ## fit the model on training data
# Out:
# LinearRegression(n_jobs=-1)

# %%
print('This is our coefficient or slope:',regression.coef_) ## slope of the line  its done by formula y^=B0+B1*x1 Y^ is prdicted value B0 is intercept and B1 is slope x1 is input feature our weight
print('This is our intercept:',regression.intercept_)
# Out:
# This is our coefficient or slope: [17.2982057]
# This is our intercept: 156.47058823529412

# %% [markdown]
# ##### The 1 unit movement in our weight(input feature) leads to 17.29 unit movement in out height(output feature).
# ##### The intercept is where the bestfit line cuts y axis (y intercept).

# %%
## plot traning data point  best fit line 
plt.scatter(x_train, y_train)
plt.plot(x_train, regression.predict(x_train), color='red') ## best fit line
plt.xlabel('Weight (kg)')
plt.ylabel('Height (cm)')
# Out:
# Text(0, 0.5, 'Height (cm)')

# %%
## prediction for test data
y_pred=regression.predict(x_test) ## this will give us the predicted value for test data

# %% [markdown]
# ### prediction of data
# #### 1. predicted height output= intercept + coeffi_(weight)
# #### 2. Y_pred_test=156.47+17.29(X_text)

# %%
## performance metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mse=mean_squared_error(y_test, y_pred) ## mean squared error
mae=mean_absolute_error(y_test, y_pred) ## mean absolute error
rmse=np.sqrt(mse) ## root mean squared error
print('Mean Absolute Error:', mae)
print('Root Mean Squared Error:', rmse)
print('Mean Squared Error:', mse)
# Out:
# Mean Absolute Error: 9.66512588679501
# Root Mean Squared Error: 10.716374991212605
# Mean Squared Error: 114.84069295228699

# %% [markdown]
# ### R square
# ##### formula :  R^2=1-ssr/sst
# ##### R^2 = coefficient of determination ssr = sum of residuals , sst= total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test, y_pred) ## r squared score
score
# Out:
# 0.7360826717981276

# %% [markdown]
# #### Formula for Adjusted R-Squared
# ##### adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - k - 1))
#
# ##### Components:
# ##### r2 = R-squared (coefficient of determination)
# ##### n = Number of observations (data points)
# ##### k = Number of independent variables (predictors)

# %%
## Display ajusted r squared score
1-((1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)) ## adjusted r squared score
# Out:
# 0.6701033397476595

# %% [markdown]
# ________________________________________________________________________________________________________________________

# %% [markdown]
# # linear regression using OLS

# %%
import statsmodels.api as sm

# %%
model=sm.OLS(y_train, X_train).fit() ## OLS is ordinary least square

# %%
predictions = model.predict(X_test)  ## Get predicted values
print(predictions)
# Out:
# 15    164.134205
# 9     164.134205
# 0      94.692811
# 8     199.907045
# 17    136.778504
# 12    220.949891
# dtype: float64

# %%
print(model.summary()) ## this will give us the summary of the model
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 Height   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.985
# Method:                 Least Squares   F-statistic:                              1133.
# Date:                Mon, 31 Mar 2025   Prob (F-statistic):                    2.80e-16
# Time:                        19:24:34   Log-Likelihood:                         -73.806
# No. Observations:                  17   AIC:                                      149.6
# Df Residuals:                      16   BIC:                                      150.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Weight         2.1043      0.063     33.655      0.000       1.972       2.237
# ==============================================================================
# Omnibus:                        1.339   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.512   Jarque-Bera (JB):                0.848
# Skew:                           0.120   Prob(JB):                        0.654
# Kurtosis:                       1.933   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/saketsmac/saket_udemy_ml/venv/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=17 observations were given.
#   return hypotest_fun_in(*args, **kwds)

# %%
## prediction for new data
regression.predict(scaler.transform([[70]]))
# Out:
# /Users/saketsmac/saket_udemy_ml/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([153.88159699])
